# %%
import os
print(os.getcwd())
os.chdir('/workspaces/kornia/kornia/geometry/nerf/')

from nerf import PositionalEncoder

import torch
import matplotlib.pyplot as plt
# Out:
# /workspaces/kornia/kornia/geometry/nerf/kornia_nerf_jupyter

# %%
pos_enc = PositionalEncoder(3, 10, log_space=False)

# %%
n = 100
x = torch.linspace(0., 1., n)
y = torch.zeros(n)
z = torch.zeros(n)

torch.stack([x, y, z], dim = -1).shape
# Out:
# torch.Size([100, 3])

# %%
a = pos_enc(torch.stack([x, y, z], dim = -1))
a.shape
# Out:
# torch.Size([100, 63])

# %%
plt.plot(a[:, 0 : 10])
# Out:
# [<matplotlib.lines.Line2D at 0x7fe7cbd53fa0>,
#  <matplotlib.lines.Line2D at 0x7fe7cbd53f70>,
#  <matplotlib.lines.Line2D at 0x7fe7cbd8b100>,
#  <matplotlib.lines.Line2D at 0x7fe7cbd8b220>,
#  <matplotlib.lines.Line2D at 0x7fe7cbd8b340>,
#  <matplotlib.lines.Line2D at 0x7fe7cbd8b460>,
#  <matplotlib.lines.Line2D at 0x7fe7cbd8b580>,
#  <matplotlib.lines.Line2D at 0x7fe7cbd8b6a0>,
#  <matplotlib.lines.Line2D at 0x7fe7cbd8b7c0>,
#  <matplotlib.lines.Line2D at 0x7fe7cbd8b8e0>]

# %%
pos_enc._d_input
# Out:
# 5

# %%
pos_enc._d_output
# Out:
# 55
